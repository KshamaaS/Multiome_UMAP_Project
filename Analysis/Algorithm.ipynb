# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
project_dir = "/content/drive/MyDrive/Multiome_UMAP_Project/notebooks/analysis"
os.makedirs(project_dir, exist_ok=True)
os.chdir(project_dir)

# %%
# !pip install muon igraph leidenalg crc32c
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.7/293.7 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 126.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 45.7 MB/s eta 0:00:00
# ...

# %%
# !python multimodal_preprocess_pipeline.py --input_path /content/drive/MyDrive/Multiome_UMAP_Project/data/processed/GSE140203_SHARE_seq_processed.h5mu --output_dir /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results --integration_strategy concat_pca \
  --n_rna_dims 30 \
  --n_atac_dims 30
# Out:
# 2025-11-20 21:11:52.475617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763673112.502497     674 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763673112.510177     674 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763673112.530398     674 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate_dual_umap_quality.py
# Out:
# ...
# DUAL-UMAP QUALITY EVALUATION
# ...
#
# Loading processed data with UMAPs...
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
#
# ✓ Data loaded successfully!
#   Cells: 34,774
#
# ...

# %%
# !python coupled_umap_with_wnn.py --input_path /content/drive/MyDrive/Multiome_UMAP_Project/data/processed/GSE140203_SHARE_seq_processed.h5mu --output_dir /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn --integration_strategy wnn \
  --n_rna_dims 30 \
  --n_atac_dims 30
# Out:
# 2025-12-18 19:35:28.768684: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-18 19:35:28.771556: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-18 19:35:28.779223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766086528.795291    1223 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766086528.799323    1223 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python evaluate2.py --input /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn --output /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn/evaluaton
# Out:
# ...
# DUAL-UMAP QUALITY EVALUATION
# ...
#
# Loading processed data from: /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn/processed_mdata.h5mu
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# ...

# %%
# !python coupled_umap_with_wnn.py --input_path /content/drive/MyDrive/Multiome_UMAP_Project/data/processed/GSE140203_SHARE_seq_processed.h5mu --output_dir /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn3 \
--integration_strategy coupling \
  --n_rna_dims 30 \
  --n_atac_dims 30 \
  --coupling_alpha 0.5
# Out:
# 2025-12-18 22:07:05.630678: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-18 22:07:05.636067: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-18 22:07:05.649587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766095625.675181     823 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766095625.682579     823 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python evaluate2.py --input /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn2 --output /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn2/evaluaton
# Out:
# ...
# DUAL-UMAP QUALITY EVALUATION
# ...
#
# Loading processed data from: /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn2/processed_mdata.h5mu
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# ...

# %%
# !python coupled_umap_with_wnn.py --input_path /content/drive/MyDrive/Multiome_UMAP_Project/data/processed/GSE140203_SHARE_seq_processed.h5mu --output_dir /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn4 \
--integration_strategy coupling \
  --n_rna_dims 30 \
  --n_atac_dims 30 \
  --coupling_alpha 0.5
# Out:
# 2025-12-18 23:05:24.863404: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-18 23:05:24.882887: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766099124.904684    1388 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766099124.911322    1388 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python evaluate2.py --input /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn4 --output /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn3/evaluaton
# Out:
# ...
# DUAL-UMAP QUALITY EVALUATION
# ...
#
# Loading processed data from: /content/drive/MyDrive/Multiome_UMAP_Project/results/gse140203_results_wnn4/processed_mdata.h5mu
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.12/dist-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# ...
